# %%
#program to plot DOS 

#need to manually replace the fermi energy for each materials for this to work

import matplotlib.pyplot as plt
from matplotlib import rcParamsDefault
import numpy as np
# %matplotlib inline

# load data
data = np.loadtxt("/Users/guilhermegarcia/GLCGarcia documents /University /3rd year 2023 /Summer Development Internship /DOS_anaylis/Ni/NiH_dos.dat")
data2 = np.loadtxt('/Users/guilhermegarcia/GLCGarcia documents /University /3rd year 2023 /Summer Development Internship /DOS_anaylis/Fe/Fe3H8_dos.dat')
data_FeH3 = np.loadtxt("/Users/guilhermegarcia/GLCGarcia documents /University /3rd year 2023 /Summer Development Internship /DOS_anaylis/Fe/FeH3_dos.dat")
print(data[:,0])

energy1 = data[:,0]
dos1 = data[:,1]
idos1 = data[:,2]

energy2 = data2[:,0]
dos2 = data2[:,1]
idos2 = data2[:,2]

energy_FeH3 = data_FeH3[:,0]
dos_FeH3 = data_FeH3[:,1]
idos_FeH3 = data_FeH3[:,2]

# make plot
e_f = 166.549
plt.figure(figsize = (12, 6))
plt.plot(energy1, dos1, linewidth=0.75, color='red')
plt.yticks([])
plt.xlabel('Energy (eV)')
plt.ylabel('DOS')
plt.axvline(x=e_f, linewidth=0.5, color='k', linestyle=(0, (8, 10)))
#plt.xlim(-6, 16)
plt.ylim(0, )
plt.fill_between(energy1, 0, dos1, where=(energy1 < e_f), facecolor='red', alpha=0.25)
#plt.text(6, 1.7, 'Fermi energy',  rotation=90)
plt.title("NiH")
plt.show()
# Out:
# [ -3.458  -3.448  -3.438 ... 215.392 215.402 215.412]
