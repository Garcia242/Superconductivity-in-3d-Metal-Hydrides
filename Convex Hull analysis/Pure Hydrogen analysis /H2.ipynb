# %%
import pandas as pd
#pip install numpy

import numpy as np

import matplotlib.pyplot as plt 

#inport data from .dat files 
energy_datap63 = pd.read_csv("/Users/guilhermegarcia/Documents/GLCGarcia documents /University /3rd year 2023 /Summer Development Internship /Pure Hydrogen analysis /energiesp63.dat", sep = " ", header = None)
energy_data2c = pd.read_csv("/Users/guilhermegarcia/Documents/GLCGarcia documents /University /3rd year 2023 /Summer Development Internship /Pure Hydrogen analysis /energies2c.dat", sep = " ", header = None)
press2c = pd.read_csv("/Users/guilhermegarcia/Documents/GLCGarcia documents /University /3rd year 2023 /Summer Development Internship /Pure Hydrogen analysis /press2c.dat", sep = " ", header = None)
pressp63 = pd.read_csv("/Users/guilhermegarcia/Documents/GLCGarcia documents /University /3rd year 2023 /Summer Development Internship /Pure Hydrogen analysis /pressp63.dat", sep = " ", header = None)

energies2c = np.array(energy_data2c.iloc[:, 2])
energiesp63 = np.array(energy_datap63.iloc[:, 2])

press2c = np.array(press2c)
pressp63 = np.array(pressp63)

# change into GPa units

press2c = press2c / 10
pressp63 = pressp63 / 10

print(energiesp63)

plt.plot(press2c , energies2c/24, "." , label = "C2/c - 24") # we should have 12 ions per unit cell, which makes sense, but why did POSTCAR found 24 ins
plt.plot (pressp63 , energiesp63/16, ".", label = "P63/m" )
plt.legend()
plt.show()

#plt.axis("equal")
# Out:
# [-54.255079   -50.119245   -47.276398   -44.860817   -42.696893
#  -40.70775    -38.850681   -37.099015   -35.434464   -33.843136
#  -32.315202   -29.418318   -26.696506   -24.117949   -21.659646
#  -19.304397   -17.039068   -14.852949   -12.737604   -10.685885
#   -8.6917912   -6.7504562   -4.8575671   -3.0092629   -1.2023476
#    0.56602117   2.2983221    3.9970743    5.6641515    7.3013877
#  262.31751    274.49339    286.66926    298.84513    311.02101   ]
